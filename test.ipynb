# %%
code = [33, 56, 46, 44, 62, 13, 44, 36, 63, 62, 61, 44, 46, 40, 96, 36, 35, 57, 40, 33, 33, 36, 42, 40, 35, 46, 40, 99, 46, 34, 32]

print(chr(code[0]), chr(code[1]))

print(max(code))
print(min(code))

import statistics
print('mode', statistics.mode(code))

print([chr(c) for c in code])
# Out:
# ! 8
# 99
# 13
# mode 46
# ['!', '8', '.', ',', '>', '\r', ',', '$', '?', '>', '=', ',', '.', '(', '`', '$', '#', '9', '(', '!', '!', '$', '*', '(', '#', '.', '(', 'c', '.', '"', ' ']

# %%
key = 77
code_str = ""
for c in code:
    code_str += chr(c ^ key)
print(code_str)
# Out:
# lucas@airspace-intelligence.com
